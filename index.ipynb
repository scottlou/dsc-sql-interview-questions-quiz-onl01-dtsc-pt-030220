# %% [markdown]
# # SQL Interview Questions  - Quiz
#
#
# ## Introduction
#
# This quiz contains questions on topics you can expect to see in an interview pertaining to SQL and Relational Databases. Some of them are multiple choice, while some are short answer. For these short answer questions, double click on the Jupyter Notebook and type your answer below the line.
#
# ## Question 1
#
# What are the 4 main datatypes in SQLite3? Can we use other common types from other kinds of SQL?
#
# Type your answer below this line:
#
# ### The ones we learned we INTEGER, NULL, TEXT, BLOB. REAL is the other.
#
#
#
#
#
# ## Question 2
#
# Explain the relationship between **Primary Keys** and **Foreign Keys**.
#
# Type your answer below this line:
#
# ### Primary key is used to UNIQUELY identify records in a rable, whereas forweign key establishes a relationship between tables.
#
#
#
#
# ## Question 3
#
# Explain the different types of relationships entities can have in a SQL database.
#
# Type your answer below this line:
#
# ### ONE-TO-ONE: both tables can only have one recoed on either side of the relationship, each primkey val relates to one or no record in related table (married/spouse input-outputs)
#
# ### ONE-TO-MANY: primary key table contains only one record that relates to none, one , or many records in related table (one mother, many children)
#
# ### MANY-TO-MANY: each record in both trables can relate to any numbeer of records or none in the other table
#
#
# ## Question 4
#
# Explain the various types of JOINs possible with SQL.
#
# Type your answer below this line: http://www.sql-join.com/sql-join-types
#
# ### INNER JOIN: select all records from both tables where join condition is met
# ### FULL JOIN: select all records whether condition is met or not
# ### LEFT / RIGHT JOIN: select all records from primary table along with records from alternate table that fit condition
#
#
#
#
# ## Question 5
#
# Explain the relationship between Aggregate functions and GROUP BY statements.
#
# Type your answer below this line:
#
# ### GROUP BY arranges rows into groups and AGG function returns the summary (count, min, max, average, sum, etc.) for each group
#
#
#
# ## Question 6
#
# What role do Associative Entities play (JOIN Tables) in many-to-many JOINs?
#
#
# Type your answer below this line:
#
# ### the associative entity is the table and USING/ON values that associates two other tables in a MANY-TO-MANY relationshp
#
#
#
# ## Summary
#
# In this lesson, we practiced answering open-ended interview questions for SQL and Relational Databases.
